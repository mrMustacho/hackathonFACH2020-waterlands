# %% [markdown]
# # Hackathon Immersion Day
# **Camilo Valenzuela - Software Engineer - Data Observatory**
#
# Este es un pequeño tutorial mostrando las distintas formas de acceder a los datos que se proveen en la Hackathon.
#
# Se tienen dos tipos de datos:
# 1. Imagenes tif (SAF) en un Bucket de AWS S3.
# 2. Datos dentro del DataCube.

# %% [markdown]
# # Accediendo al DataCube
#
# Para acceder al DataCube se utiliza el paquete `datacube` (https://github.com/opendatacube/datacube-core) de Open DataCube

# %%
import datacube
from odc.ui import DcViewer
from deafrica_plotting import display_map

# %% [markdown]
# ## Crear una conexion al datacube
#
# Al crear una conexion con el DataCube se genera automaticamente la conexión con los datos dispobiles para la Hackathon

# %%
dc = datacube.Datacube(app="ImmersionDay")

# %% [markdown]
# ## Dentro del data cube existen distintos productos

# %%
# ?dc.list_products
# Out:
# Signature: dc.list_products(show_archived=False, with_pandas=True)
# Docstring:
# List products in the datacube
#
# :param show_archived: include products that have been archived.
# :param with_pandas: return the list as a Pandas DataFrame, otherwise as a list of dict.
# :rtype: pandas.DataFrame or list(dict)
# File:      /env/lib/python3.6/site-packages/datacube/api/core.py
# Type:      method

# %%
products = dc.list_products()
products[["name", "description"]]
# Out:
#                    name                                        description
# id
# 1    usgs_espa_ls5c1_sr  Landsat 5 USGS Collection 1 Surface Reflectanc...
# 2    usgs_espa_ls7c1_sr  Landsat 7 USGS Collection 1 Surface Reflectanc...
# 5    usgs_espa_ls8c1_ar  Landsat 8 USGS Collection 1 Aquatic Reflectanc...
# 3    usgs_espa_ls8c1_sr  Landsat 8 USGS Collection 1 Surface Reflectanc...
# 6   usgs_espa_ls8c1_toa  Landsat 8 USGS Collection 1 TOA and Brightness...
# 4   usgs_espa_ls8c1_veg  Landsat 8 USGS Collection 1 Vegetation Indices...

# %% [markdown]
# ## Para cada producto se tienen varias mediciones

# %%
# ?dc.list_measurements
# Out:
# Signature: dc.list_measurements(show_archived=False, with_pandas=True)
# Docstring:
# List measurements for each product
#
# :param show_archived: include products that have been archived.
# :param with_pandas: return the list as a Pandas DataFrame, otherwise as a list of dict.
# :rtype: pandas.DataFrame or list(dict)
# File:      /env/lib/python3.6/site-packages/datacube/api/core.py
# Type:      method

# %%
measurements = dc.list_measurements()
measurements.head(20)
# Out:
#                                            name   dtype        units  nodata  \
# product            measurement
# usgs_espa_ls5c1_sr blue                    blue   int16  reflectance   -9999
#                    green                  green   int16  reflectance   -9999
#                    red                      red   int16  reflectance   -9999
#                    nir                      nir   int16  reflectance   -9999
#                    swir1                  swir1   int16  reflectance   -9999
#                    swir2                  swir2   int16  reflectance   -9999
#                    atmos_opacity  atmos_opacity   int16            1   -9999
#                    pixel_qa            pixel_qa  uint16    bit_index       1
#                    radsat_qa          radsat_qa   uint8    bit_index       1
#                    ledaps_qa          ledaps_qa   uint8    bit_index       0
# usgs_espa_ls7c1_sr blue                    blue   int16  reflectance   -9999
#                    green                  green   int16  reflectance   -9999
#                    red                      red   int16  reflectance   -9999
#                    nir                      nir   int16  reflectance   -9999
#                    swir1                  swir1   int16  reflectance   -9999
#                    swir2                  swir2   int16  reflectance   -9999
#                    atmos_opacity  atmos_opacity   int16            1   -9999
#                    pixel_qa            pixel_qa  uint16    bit_index       1
#                    radsat_qa          radsat_qa   uint8    bit_index       1
#                    ledaps_qa          ledaps_qa   uint8    bit_index       0
#
#                                                      aliases  \
# product            measurement
# usgs_espa_ls5c1_sr blue                   [sr_band1, band_1]
#                    green                  [sr_band2, band_2]
#                    red                    [sr_band3, band_3]
#                    nir                    [sr_band4, band_4]
#                    swir1                  [sr_band5, band_5]
#                    swir2                  [sr_band7, band_7]
#                    atmos_opacity          [sr_atmos_opacity]
#                    pixel_qa       [pixel_quality, level2_qa]
#                    radsat_qa                 [saturation_qa]
#                    ledaps_qa                   [sr_cloud_qa]
# usgs_espa_ls7c1_sr blue                   [sr_band1, band_1]
#                    green                  [sr_band2, band_2]
#                    red                    [sr_band3, band_3]
#                    nir                    [sr_band4, band_4]
#                    swir1                  [sr_band5, band_5]
#                    swir2                  [sr_band7, band_7]
#                    atmos_opacity          [sr_atmos_opacity]
#                    pixel_qa       [pixel_quality, level2_qa]
#                    radsat_qa                 [saturation_qa]
#                    ledaps_qa                   [sr_cloud_qa]
#
#                                                                    flags_definition
# product            measurement
# usgs_espa_ls5c1_sr blue                                                         NaN
#                    green                                                        NaN
#                    red                                                          NaN
#                    nir                                                          NaN
#                    swir1                                                        NaN
#                    swir2                                                        NaN
#                    atmos_opacity                                                NaN
#                    pixel_qa       {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
#                    radsat_qa      {'data_fill': {'bits': 0, 'values': {'0': 'val...
#                    ledaps_qa      {'ddv': {'bits': 0, 'values': {'0': False, '1'...
# usgs_espa_ls7c1_sr blue                                                         NaN
#                    green                                                        NaN
#                    red                                                          NaN
#                    nir                                                          NaN
#                    swir1                                                        NaN
#                    swir2                                                        NaN
#                    atmos_opacity                                                NaN
#                    pixel_qa       {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
#                    radsat_qa      {'data_fill': {'bits': 0, 'values': {'0': 'val...
#                    ledaps_qa      {'ddv': {'bits': 0, 'values': {'0': False, '1'...

# %%
product = "usgs_espa_ls8c1_veg"
measurements.loc[product]
# Out:
#                  name   dtype      units  nodata                     aliases  \
# measurement
# ndvi             ndvi   int16          1   -9999                   [sr_ndvi]
# evi               evi   int16          1   -9999                    [sr_evi]
# pixel_qa     pixel_qa  uint16  bit_index       1  [pixel_quality, level2_qa]
#
#                                               flags_definition
# measurement
# ndvi                                                       NaN
# evi                                                        NaN
# pixel_qa     {'snow': {'bits': 4, 'values': {'0': 'no_snow'...

# %% [markdown]
# Por ejemplo el producto *usgs_espa_ls8c1_veg* tiene dos índices de vegetación:
# - ndvi: Índice de vegetación de diferencia normalizada (Normalized difference vegetation index)
# - evi: Enhanced vegetation index

# %% [markdown]
# # Visalizar los productos

# %%
# ?DcViewer
# Out:
# Init signature: DcViewer(dc, time, products=None, zoom=None, center=None, height=None, width=None, style=None)
# Docstring:      <no docstring>
# Init docstring:
# :param dc:        Datacube object
# :param time:      Initial time as a string
# :param products:  None -- all products, 'non-empty' all non empty products, or a list or product names
# :param zoom:      Initial zoom factor for a map
# :param center:    Initial center for a map in Lat,Lon
# :param height:    Example: '600px', '10em'
# :param width:     Example: '100%', '600px'
# :param style:     Dictionary for styling for dataset footprint
#     - weight
#     - color/fillColor
#     - opacity/fillOpacity
#     - full list of options here: https://leafletjs.com/reference-1.5.0.html#path-option
# File:           /env/lib/python3.6/site-packages/odc/ui/_dc_explore.py
# Type:           type

# %%
display_ls8 = [p for p in products.name if "ls8" in p]
DcViewer(dc=dc, 
         time='2013',
         products=display_ls8,
         center=(-33.45, -70.66),
         zoom=7,
        )
# Out:
# VBox(children=(HBox(children=(Dropdown(layout=Layout(flex='0 1 auto', width='10em'), options=('usgs_espa_ls8c1…

# %% [markdown]
# ## Obteniendo datos del Data Cube
# Para este ejemplo usaremos los datos cercanos a la playa Las Docas en Valparaiso.

# %%
#Definimos nuestra zona de interés
lat_range = (-33.14, -33.16)
lon_range = (-71.72, -71.67)

#Y un rango de tiempo
time_range = ("2013-01-01", "2020-01-01")

# %%
display_map(x=lon_range, y=lat_range)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Los datos se descargan mediante `load()`.

# %%
ds = dc.load(product = product,
             longitude = lon_range,
             latitude = lat_range,
             output_crs = "EPSG:32719",
             time = time_range,
             resolution = (-25, 25),
             dask_chunks = {"time": 1}
            )
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 154, x: 190, y: 94)
# Coordinates:
#   * time         (time) datetime64[ns] 2013-04-12T14:35:27.984873 ... 2019-12...
#   * y            (y) float64 6.33e+06 6.33e+06 6.33e+06 ... 6.328e+06 6.328e+06
#   * x            (x) float64 2.463e+05 2.463e+05 2.463e+05 ... 2.51e+05 2.51e+05
#     spatial_ref  int32 32719
# Data variables:
#     ndvi         (time, y, x) int16 dask.array<chunksize=(1, 94, 190), meta=np.ndarray>
#     evi          (time, y, x) int16 dask.array<chunksize=(1, 94, 190), meta=np.ndarray>
#     pixel_qa     (time, y, x) uint16 dask.array<chunksize=(1, 94, 190), meta=np.ndarray>
# Attributes:
#     crs:           EPSG:32719
#     grid_mapping:  spatial_ref

# %%
ds.ndvi
# Out:
# <xarray.DataArray 'ndvi' (time: 154, y: 94, x: 190)>
# dask.array<dc_load_ndvi, shape=(154, 94, 190), dtype=int16, chunksize=(1, 94, 190), chunktype=numpy.ndarray>
# Coordinates:
#   * time         (time) datetime64[ns] 2013-04-12T14:35:27.984873 ... 2019-12...
#   * y            (y) float64 6.33e+06 6.33e+06 6.33e+06 ... 6.328e+06 6.328e+06
#   * x            (x) float64 2.463e+05 2.463e+05 2.463e+05 ... 2.51e+05 2.51e+05
#     spatial_ref  int32 32719
# Attributes:
#     units:         1
#     nodata:        -9999
#     crs:           EPSG:32719
#     grid_mapping:  spatial_ref

# %% [markdown]
# ## Visualizando los datos
#
# Los datos vienen escalados por lo que tenemos que transformarlos previo a cualquier procesamiento
#
# https://www.usgs.gov/core-science-systems/nli/landsat/landsat-surface-reflectance-derived-spectral-indices?qt-science_support_page_related_con=0#qt-science_support_page_related_con

# %%
scaled_ds = ds.ndvi[:10]*.0001
scaled_ds.plot(col="time", robust=True, col_wrap=5)

# %%
ds_ndvi = ds.ndvi * .0001
means = ds_ndvi.mean(axis=[1,2]).values

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(12,5))
plt.title("Mean NVDI")
plt.plot(means)

# %% [markdown]
# Algunas preguntas:
# - ¿Que hacemos con la nubosidad?
# - Podemos utilizar otros datos para mejorar el análisis.

# %% [markdown]
# # Objetener datos desde AWS S3

# %% [markdown]
# ## Creamos un cliente de s3

# %%
import boto3
import pandas as pd
import xarray as xr

# %%
s3 = boto3.client("s3")

# %% [markdown]
# ## Nos conectamos al bucket de la hackathon
#
# Usando boto3 podemos pedir la lista de imagenes que se tienen dentro del Bucket.

# %%
bucket = "hackathon-fach-2020"

# %%
objects = s3.list_objects(Bucket=bucket)
parsed_objects = pd.DataFrame(objects["Contents"])
parsed_objects.sort_values("Key")
# Out:
#                                                   Key  \
# 0       glaciares/Glaciar_Olivares_22052020_ms_01.tfw
# 1       glaciares/Glaciar_Olivares_22052020_ms_01.tif
# 2       glaciares/Glaciar_Olivares_22052020_ms_02.tfw
# 3       glaciares/Glaciar_Olivares_22052020_ms_02.tif
# 4       glaciares/Glaciar_Olivares_22052020_ms_03.tfw
# 5       glaciares/Glaciar_Olivares_22052020_ms_03.tif
# 6       glaciares/Glaciar_Olivares_22052020_ms_04.tfw
# 7       glaciares/Glaciar_Olivares_22052020_ms_04.tif
# 8      glaciares/Glaciar_Olivares_22052020_pan_01.tfw
# 9      glaciares/Glaciar_Olivares_22052020_pan_01.tif
# 10     glaciares/Glaciar_Olivares_22052020_pan_02.tfw
# 11     glaciares/Glaciar_Olivares_22052020_pan_02.tif
# 12     glaciares/Glaciar_Olivares_22052020_pan_03.tfw
# 13     glaciares/Glaciar_Olivares_22052020_pan_03.tif
# 14     glaciares/Glaciar_Olivares_22052020_pan_04.tfw
# 15     glaciares/Glaciar_Olivares_22052020_pan_04.tif
# 16                                glaciares/Thumbs.db
# 17                             humedal/yali_3a_ms.tfw
# 18                             humedal/yali_3a_ms.tif
# 19                            humedal/yali_3a_pan.tfw
# 20                            humedal/yali_3a_pan.tif
# 21                       incendios/04082020/Thumbs.db
# 22      incendios/04082020/Valparaiso_04082020_ms.tfw
# 23      incendios/04082020/Valparaiso_04082020_ms.tif
# 24     incendios/04082020/Valparaiso_04082020_pan.tfw
# 25     incendios/04082020/Valparaiso_04082020_pan.tif
# 26                       incendios/06022020/Thumbs.db
# 27   incendios/06022020/Valparaiso_06022020_ms_01.tfw
# 28   incendios/06022020/Valparaiso_06022020_ms_01.tif
# 29   incendios/06022020/Valparaiso_06022020_ms_02.tfw
# 30   incendios/06022020/Valparaiso_06022020_ms_02.tif
# 31  incendios/06022020/Valparaiso_06022020_pan_01.tfw
# 32  incendios/06022020/Valparaiso_06022020_pan_01.tif
# 33  incendios/06022020/Valparaiso_06022020_pan_02.tfw
# 34  incendios/06022020/Valparaiso_06022020_pan_02.tif
# 35                       incendios/20042020/Thumbs.db
# 36      incendios/20042020/Valparaiso_20042020_ms.tfw
# 37      incendios/20042020/Valparaiso_20042020_ms.tif
# 38     incendios/20042020/Valparaiso_20042020_pan.tfw
# 39     incendios/20042020/Valparaiso_20042020_pan.tif
# 40                       incendios/26012020/Thumbs.db
# 41   incendios/26012020/Valparaiso_26012020_ms_01.tfw
# 42   incendios/26012020/Valparaiso_26012020_ms_01.tif
# 43   incendios/26012020/Valparaiso_26012020_ms_02.tfw
# 44   incendios/26012020/Valparaiso_26012020_ms_02.tif
# 45  incendios/26012020/Valparaiso_26012020_pan_01.tfw
# 46  incendios/26012020/Valparaiso_26012020_pan_01.tif
# 47  incendios/26012020/Valparaiso_26012020_pan_02.tfw
# 48  incendios/26012020/Valparaiso_26012020_pan_02.tif
#
#                 LastModified                                   ETag  \
# 0  2020-12-03 18:52:26+00:00     "d6b808421e4058894d844f442af8138f"
# 1  2020-12-03 18:59:38+00:00   "07c41a2c478836db0e489979fce65d96-6"
# 2  2020-12-03 18:52:26+00:00     "28d94790c25a38c246c50c8d4cb0529a"
# 3  2020-12-03 18:59:35+00:00   "02c8543611b903d9a5dab72b2272f540-6"
# 4  2020-12-03 18:52:26+00:00     "a60938313cad0c5b1b40844e5cb3b3f4"
# 5  2020-12-03 18:59:31+00:00   "0b047a3b8065090840e683801ae7bec6-6"
# 6  2020-12-03 18:52:26+00:00     "2e5c20ad6097490acafea3af2f6a440c"
# 7  2020-12-03 18:59:32+00:00   "320ca452c0999b5a6c0c4f2816ead4d0-6"
# 8  2020-12-03 18:52:26+00:00     "4161f25edf9b2204abd3cbeabedd67da"
# 9  2020-12-03 18:59:41+00:00  "b88685c4f95138c3fd3d9ca6ec6e466d-23"
# 10 2020-12-03 18:52:26+00:00     "5810dd89f5999d2d6c71b835498be76d"
# 11 2020-12-03 18:59:50+00:00  "b506f26f0adceca75802a0f9e8500733-23"
# 12 2020-12-03 18:52:27+00:00     "d34d74015e359d238b17946a585e3188"
# 13 2020-12-03 18:59:57+00:00  "a9f6e29b4df00a76ef26f99783c3625a-23"
# 14 2020-12-03 18:52:27+00:00     "a0a2b15b0cc1aafe7dbfa3b84842be89"
# 15 2020-12-03 19:00:07+00:00  "b52215427129d6f65dfb4f613e280a30-23"
# 16 2020-12-03 18:52:27+00:00     "e82cdc512ea4cb459b15716b71ec0eb2"
# 17 2020-12-03 18:53:46+00:00     "06abdd5b68d9a28c72aed120add0e9dd"
# 18 2020-12-03 18:57:51+00:00  "83a0655cdfc478ce33605938ee806f7f-10"
# 19 2020-12-03 18:53:47+00:00     "a6cf02fbf45b4fe281af36b024e98612"
# 20 2020-12-03 18:57:54+00:00  "fd3969fe05e90cbd37ccd2c50a4af6c4-19"
# 21 2020-12-03 18:54:59+00:00     "6961d48e8d6b4b24e6b51dd7bd65d3a9"
# 22 2020-12-03 18:54:59+00:00     "15c32d3c20475281b62982520a0db1b4"
# 23 2020-12-03 18:58:09+00:00   "f9a05bc261d812aed00a080bd6e4475e-7"
# 24 2020-12-03 18:54:59+00:00     "ee99de514e3d4e95a8a4459054ff86ae"
# 25 2020-12-03 18:58:10+00:00  "0f07ad744858384c7f6c3e79024c0cd2-25"
# 26 2020-12-03 18:54:59+00:00     "2902e8e677a7375bd6f19f08d6e1223c"
# 27 2020-12-03 18:54:59+00:00     "926d47e731e76d77d494c701657004ef"
# 28 2020-12-03 18:58:22+00:00   "fbc1fd31cc0717f986ea6911f2c613c1-5"
# 29 2020-12-03 18:54:59+00:00     "c6ab0adfb68f56dd3e91135a57314074"
# 30 2020-12-03 18:58:20+00:00   "77ea2f57a604c4b294e098967965dcf8-5"
# 31 2020-12-03 18:54:59+00:00     "3e5826440fc8a3ebd1b068eda35aae53"
# 32 2020-12-03 18:58:23+00:00  "79ba2598b84af5d244fa024b382d219c-18"
# 33 2020-12-03 18:55:00+00:00     "0176df2e339b1e888bd60309e7e7fe57"
# 34 2020-12-03 18:58:30+00:00  "67398bfa149691942838082568a08816-18"
# 35 2020-12-03 18:55:00+00:00     "21a859a79d02f3ba55f935b27a5138a3"
# 36 2020-12-03 18:55:00+00:00     "f06148df0336ad928faa997c3804d014"
# 37 2020-12-03 18:58:39+00:00   "631fa3b7f515ae25c8e0712d5b57d420-5"
# 38 2020-12-03 18:55:00+00:00     "c098555271b2d021836274ca2b83f228"
# 39 2020-12-03 18:58:40+00:00  "e40f67b641716782204c61a1a3733f5e-18"
# 40 2020-12-03 18:55:00+00:00     "eb2a94f72299a6f593620ddd914fd01b"
# 41 2020-12-03 18:55:00+00:00     "7f9c6c2401fc3b8cac0084593919eea6"
# 42 2020-12-03 18:58:37+00:00   "ca42d50025cd99d9ceecdd2687a9ff5c-6"
# 43 2020-12-03 18:55:00+00:00     "d15eef9cb21de1a9a2b2c615ee8bad53"
# 44 2020-12-03 18:58:47+00:00   "30e4d43e4dae38a22d49987779358ac7-6"
# 45 2020-12-03 18:55:00+00:00     "3b1ee6dd1abe625c5d27055b5f057fda"
# 46 2020-12-03 18:58:50+00:00  "713c4504afbcd08f4826b26e4ab56096-22"
# 47 2020-12-03 18:55:00+00:00     "9505beee25e3bf97324e44ec08757cbc"
# 48 2020-12-03 18:58:57+00:00  "6075eb2a36a05a41515d41e941e582e9-22"
#
#          Size StorageClass
# 0          99     STANDARD
# 1    48509030     STANDARD
# 2          99     STANDARD
# 3    48509030     STANDARD
# 4          99     STANDARD
# 5    47296318     STANDARD
# 6          99     STANDARD
# 7    47296318     STANDARD
# 8          99     STANDARD
# 9   189248334     STANDARD
# 10         99     STANDARD
# 11  189248334     STANDARD
# 12         99     STANDARD
# 13  188042934     STANDARD
# 14         99     STANDARD
# 15  189322134     STANDARD
# 16      10752     STANDARD
# 17         85     STANDARD
# 18   75498296     STANDARD
# 19         85     STANDARD
# 20  156396470     STANDARD
# 21       4096     STANDARD
# 22         99     STANDARD
# 23   52311046     STANDARD
# 24         99     STANDARD
# 25  205262934     STANDARD
# 26       4096     STANDARD
# 27         99     STANDARD
# 28   37889606     STANDARD
# 29         99     STANDARD
# 30   37889606     STANDARD
# 31         99     STANDARD
# 32  147239734     STANDARD
# 33         99     STANDARD
# 34  147239734     STANDARD
# 35       4096     STANDARD
# 36         99     STANDARD
# 37   37889606     STANDARD
# 38         99     STANDARD
# 39  147231534     STANDARD
# 40       4096     STANDARD
# 41         99     STANDARD
# 42   46018054     STANDARD
# 43         99     STANDARD
# 44   46018054     STANDARD
# 45         99     STANDARD
# 46  178153734     STANDARD
# 47         99     STANDARD
# 48  176899134     STANDARD

# %%
file = "incendios/04082020/Valparaiso_04082020_pan.tif"
file_path = f's3://{bucket}/{file}'
file_path
# Out:
# 's3://hackathon-fach-2020/incendios/04082020/Valparaiso_04082020_pan.tif'

# %% [markdown]
# ### Cargamos los datos en un xarray

# %%
# Si se agrega chunks los datos se cargan mediante Dask, si no con Numpy.
da = xr.open_rasterio(file_path, chunks={'x': 500, 'y': 500})
da
# Out:
# <xarray.DataArray (band: 1, y: 10714, x: 9474)>
# dask.array<open_rasterio-61e9815200008d0f14b9f43eda92e7ff<this-array>, shape=(1, 10714, 9474), dtype=uint16, chunksize=(1, 500, 500), chunktype=numpy.ndarray>
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 -33.07 -33.07 -33.07 -33.07 ... -33.21 -33.21 -33.21
#   * x        (x) float64 -71.72 -71.72 -71.72 -71.72 ... -71.58 -71.58 -71.58
# Attributes:
#     transform:               (1.557301042984249e-05, 0.0, -71.72302255794712,...
#     crs:                     +init=epsg:4326
#     res:                     (1.557301042984249e-05, 1.304016942622471e-05)
#     is_tiled:                1
#     nodatavals:              (nan,)
#     scales:                  (1.0,)
#     offsets:                 (0.0,)
#     AREA_OR_POINT:           Area
#     TIFFTAG_RESOLUTIONUNIT:  2 (pixels/inch)
#     TIFFTAG_SOFTWARE:        ERDAS IMAGINE
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1

# %%
slice_data = da.sel(band=1, y=slice(*lat_range), x = slice(*lon_range))
slice_data
# Out:
# <xarray.DataArray (y: 1534, x: 3211)>
# dask.array<getitem, shape=(1534, 3211), dtype=uint16, chunksize=(500, 500), chunktype=numpy.ndarray>
# Coordinates:
#     band     int64 1
#   * y        (y) float64 -33.14 -33.14 -33.14 -33.14 ... -33.16 -33.16 -33.16
#   * x        (x) float64 -71.72 -71.72 -71.72 -71.72 ... -71.67 -71.67 -71.67
# Attributes:
#     transform:               (1.557301042984249e-05, 0.0, -71.72302255794712,...
#     crs:                     +init=epsg:4326
#     res:                     (1.557301042984249e-05, 1.304016942622471e-05)
#     is_tiled:                1
#     nodatavals:              (nan,)
#     scales:                  (1.0,)
#     offsets:                 (0.0,)
#     AREA_OR_POINT:           Area
#     TIFFTAG_RESOLUTIONUNIT:  2 (pixels/inch)
#     TIFFTAG_SOFTWARE:        ERDAS IMAGINE
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1

# %%
# Cargando los datos en memoria
slice_data = slice_data.load()
slice_data.plot()

# %% [markdown]
# **Para trabajar fuera de jupyterhub descargar los datos y luego cargarlos de manera local**

# %% [markdown]
# ## Descargando los datos localmente
#
# Para descargar los datos al jupyterhub utilizamos el AWS Cli.
#
# ```bash
# aws s3 cp s3://<bucket>/<archivo> <path_dentro_de_jupyterhub>
# ```

# %%
! aws s3 cp 's3://hackathon-fach-2020/incendios/04082020/Valparaiso_04082020_pan.tif' .
# Out:
# download: s3://hackathon-fach-2020/incendios/04082020/Valparaiso_04082020_pan.tif to ./Valparaiso_04082020_pan.tif

# %% [markdown]
# La cuenta de jupyterhub tiene un limite de 20GB de disco duro.
